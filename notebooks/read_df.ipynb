# %% [markdown]
# # pyatspm Data Exploration Notebook
#
# Load and explore processed ATSPM data from an intersection's SQLite database.
# Current repo: uses per-intersection DB (`<intersection>/2068_data.db`), with tables `events`, `cycles`, `config`, `metadata`.
# Prefer `get_legacy_dataframe()` for flat format compatible with old code; or direct SQL for flexibility.
#
# **Setup**: Adjust `intersection_folder` below.

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
import sqlite3
from pathlib import Path

# Optional: if pyatspm installed
try:
    from atspm.data.reader import get_events_with_cycles_df, get_config_df
    from atspm.data.manager import DatabaseManager
    USE_ATSPM_UTILS = True
except ImportError:
    USE_ATSPM_UTILS = False
    print("pyatspm utils not found; falling back to direct SQL")
# Out:
# pyatspm utils not found; falling back to direct SQL

# %%
# ── Parameters ───────────────────────────────────────────────────────────────
intersection_folder = "2068_US-95_and_SH-8"  # change this
intersection_folder = "201_SH-55_and_Banks-Lowman_Rd"
base_dir = Path("../intersections")
db_path = base_dir / intersection_folder / f"{intersection_folder.split('_')[0]}_data.db"

print(f"DB path: {db_path}")
print(f"Exists: {db_path.exists()}")
# Out:
# DB path: ..\intersections\201_SH-55_and_Banks-Lowman_Rd\201_data.db
# Exists: True

# %% [markdown]
# ## Quick Metadata & Config Check

# %%
if USE_ATSPM_UTILS:
    with DatabaseManager(db_path) as mgr:
        meta = mgr.get_metadata()
        print("Metadata:", meta)
else:
    with sqlite3.connect(db_path) as conn:
        meta = pd.read_sql("SELECT * FROM metadata", conn)
        print(meta)
# Out:
#    lock_id intersection_id        intersection_name controller_ip  \
# 0        1             201  SH-55 & Banks-Lowman Rd  10.37.23.200
#
#   detection_type  detection_ip major_road_route major_road_name  \
# 0      Evo Radar  10.37.23.201            SH-55            None
#
#   minor_road_route  minor_road_name latitude longitude     timezone agency_id
# 0             None  Banks-Lowman Rd     None      None  US/Mountain      None

# %%
# Config for a specific date (dynamic columns)
date_str = "2025-06-15"  # example
if USE_ATSPM_UTILS:
    config = get_config_df(db_path, date_str)
    print(config.head(20))  # Series with prefixed keys like TM_EBL, Det_P2_Arrival

# %% [markdown]
# ## Load Data (Legacy Flat Format – Recommended for Exploration)

# %%
start_time = "2025-06-15 00:00:00"
end_time   = "2025-06-16 00:00:00"

if USE_ATSPM_UTILS:
    df = get_events_with_cycles_df(db_path, start_time, end_time)
    print(f"Loaded {len(df):,} rows")
    display(df.head())
    print(df['Code'].value_counts())
else:
    print("Fallback: write your own SQL JOIN similar to get_events_with_cycles_df")

# %% [markdown]
# ## Direct SQL Examples (Flexible)

# %%
start_time = "2026-06-12 00:00:00"
end_time   = "2026-06-15 00:00:00"

with sqlite3.connect(db_path) as conn:
    # Events in a time window
    query = """
    SELECT timestamp, event_code, parameter
    FROM events
    ORDER BY timestamp
    LIMIT 10000
    """
    df_events = pd.read_sql_query(query, conn)
    print(df_events.head())
# Out:
#       timestamp  event_code  parameter
# 0  1.746484e+09         184          1
# 1  1.746484e+09         181          0
# 2  1.746484e+09          83          1
# 3  1.746484e+09          83          2
# 4  1.746484e+09          83          3

# %%
df_events[df_events['event_code'] == 31]
# Out:
#          timestamp  event_code  parameter
# 147   1.746484e+09          31          3
# 206   1.746484e+09          31          1
# 543   1.746484e+09          31          3
# 596   1.746484e+09          31          1
# 629   1.746484e+09          31          2
# ...            ...         ...        ...
# 9489  1.746486e+09          31          1
# 9536  1.746486e+09          31          2
# 9597  1.746486e+09          31          3
# 9889  1.746487e+09          31          1
# 9955  1.746487e+09          31          2
#
# [104 rows x 3 columns]

# %%
# Cycle starts
df_cycles = pd.read_sql("SELECT * FROM cycles ORDER BY cycle_start LIMIT 100", conn)
display(df_cycles)
# Out:
#      cycle_start  coord_plan detection_method                 r1_phases  \
# 0   1.746484e+09           0    barrier_pulse  2,4,11,3,8,2,4,11,3,16,8
# 1   1.746484e+09           0    barrier_pulse                       2,4
# 2   1.746484e+09           0    barrier_pulse                  2,11,3,8
# 3   1.746484e+09           0    barrier_pulse                  2,11,3,8
# 4   1.746484e+09           0    barrier_pulse                      2,11
# ..           ...         ...              ...                       ...
# 95  1.746490e+09           0    barrier_pulse                         2
# 96  1.746491e+09           0    barrier_pulse                    2,4,11
# 97  1.746491e+09           0    barrier_pulse                         2
# 98  1.746491e+09           0    barrier_pulse                2,4,11,3,8
# 99  1.746491e+09           0    barrier_pulse                    2,4,11
#
#          r2_phases
# 0   6,7,8,6,7,16,8
# 1                6
# 2            6,7,8
# 3              6,8
# ...
