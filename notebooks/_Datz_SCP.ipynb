# %%
import os
import paramiko
from scp import SCPClient
import json
from datetime import datetime
import time
import ctypes
import sys
from typing import Dict, Any, Optional

# --- WINDOWS SLEEP PREVENTION ---

# Constants from winnt.h
ES_CONTINUOUS = 0x80000000
ES_SYSTEM_REQUIRED = 0x00000001
ES_DISPLAY_REQUIRED = 0x00000002

def prevent_sleep():
    """Enable system sleep prevention."""
    # Only run on Windows
    if sys.platform.startswith('win'):
        ctypes.windll.kernel32.SetThreadExecutionState(
            ES_CONTINUOUS | ES_SYSTEM_REQUIRED | ES_DISPLAY_REQUIRED
        )

def allow_sleep():
    """Allow sleep again."""
    # Only run on Windows
    if sys.platform.startswith('win'):
        ctypes.windll.kernel32.SetThreadExecutionState(ES_CONTINUOUS)

# --- STATE TRACKING HELPER FUNCTIONS ---

def get_timestamp_from_filename(filename: str) -> Optional[datetime]:
    """
    Parses 'ECON_10.70.10.51_2025_11_25_2136.datZ' -> datetime object (Naive)
    Adjust the split logic if your raw data filenames differ from this format.
    """
    try:
        base = os.path.basename(filename)
        # Remove common extensions just in case
        name_part = base.replace('.datZ', '').replace('.dat', '')
        parts = name_part.split('_')
        # Expecting last 4 parts: YYYY, MM, DD, HHMM
        date_str = "_".join(parts[-4:]) 
        return datetime.strptime(date_str, "%Y_%m_%d_%H%M")
    except Exception:
        return None

def load_state(state_path: str) -> Optional[datetime]:
    """Loads the last processed timestamp from JSON."""
    if os.path.exists(state_path):
        try:
            with open(state_path, 'r') as f:
                data = json.load(f)
                ts_str = data.get('last_processed_time')
                if ts_str:
                    return datetime.fromisoformat(ts_str)
        except Exception as e:
            print(f"Warning: Could not read state file: {e}")
    return None

def save_state(state_path: str, last_time: datetime):
    """Updates the state file."""
    try:
        with open(state_path, 'w') as f:
            json.dump({'last_processed_time': last_time.isoformat()}, f)
    except Exception as e:
        print(f"Warning: Could not save state file: {e}")

# --- MAIN DOWNLOAD FUNCTION ---

def download_remote_files(
    device_config: Dict[str, Any],
    mode: str = 'once',  # 'once' or 'continuous'
    t_hour: float = 0.25 # Time between runs for 'continuous' mode (in hours)
) -> None:
    """
    Connects to a remote device via SSH/SCP and downloads files based on timestamp.
    """
    
    # Unpack configuration
    REMOTE_HOST = device_config['host']
    REMOTE_PORT = device_config['port']
    USERNAME = device_config['user']
    PASSWORD = device_config['password']
    REMOTE_FOLDER = device_config['remote_folder']
    LOCAL_ROOT_FOLDER = device_config['local_root_folder']
    
    # Calculate sleep duration in seconds
    SLEEP_DURATION = t_hour * 60 * 60 
    
    # Define state file location
    STATE_FILE = os.path.join(LOCAL_ROOT_FOLDER, 'download_state.json')

    def _do_download():
        """The core logic for connecting and downloading."""
        print(f"[{datetime.now()}] Starting SCP download job from {REMOTE_HOST}...")

        if not os.path.exists(LOCAL_ROOT_FOLDER):
            print(f"Creating local folder: {LOCAL_ROOT_FOLDER}")
            os.makedirs(LOCAL_ROOT_FOLDER)

        # Load the last downloaded state
        last_processed_time = load_state(STATE_FILE)

        ssh = paramiko.SSHClient()
        ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        
        try:
            # 1. Connect
            ssh.connect(REMOTE_HOST, port=REMOTE_PORT, username=USERNAME, password=PASSWORD)

            # 2. List Files
            list_command = f'ls -p {REMOTE_FOLDER} | grep -v /'
            stdin, stdout, stderr = ssh.exec_command(list_command)
            output = stdout.read().decode().strip()
            files = output.splitlines()

            if not files:
                print(f"[{datetime.now()}] No files found in remote directory: {REMOTE_FOLDER}")
                return

            # 3. Filter files by timestamp
            files_to_download = []
            for file in files:
                file_ts = get_timestamp_from_filename(file)
                if file_ts:
                    if last_processed_time is None or file_ts > last_processed_time:
                        files_to_download.append((file_ts, file))
            
            # Sort by time to ensure chronological processing
            files_to_download.sort(key=lambda x: x[0])

            if not files_to_download:
                print(f"[{datetime.now()}] No new files to download since {last_processed_time}.")
                return

            # Print concise summary
            if last_processed_time:
                print(f"[{datetime.now()}] Retrieving {len(files_to_download)} files more recent than {last_processed_time}...")
            else:
                print(f"[{datetime.now()}] No state found. Retrieving all {len(files_to_download)} parseable files...")

            # 4. Download Files
            current_max_time = last_processed_time
            
            with SCPClient(ssh.get_transport()) as scp:
                for file_ts, file in files_to_download:
                    remote_path = f"{REMOTE_FOLDER}/{file}"
                    local_target_path = os.path.join(LOCAL_ROOT_FOLDER, file)
                    
                    print(f"Downloading: {file}")
                    scp.get(remote_path, local_target_path)
                    
                    # Track the latest timestamp downloaded in this batch
                    if current_max_time is None or file_ts > current_max_time:
                        current_max_time = file_ts
            
            # 5. Save the updated state
            if current_max_time and current_max_time != last_processed_time:
                save_state(STATE_FILE, current_max_time)
                print(f"[{datetime.now()}] State updated to: {current_max_time}")

            print(f"[{datetime.now()}] Download job completed successfully.")

        except paramiko.AuthenticationException:
            print(f"[{datetime.now()}] Error: Authentication failed for {USERNAME}@{REMOTE_HOST}")
        except paramiko.SSHException as e:
            print(f"[{datetime.now()}] Error: SSH connection or command failed: {e}")
        except Exception as e:
            print(f"[{datetime.now()}] General Error during download: {e}")
        finally:
            ssh.close()
            
    # --- Mode Execution Logic ---
    
    if mode == 'once':
        _do_download()
        
    elif mode == 'continuous':
        print(f"Starting continuous SCP downloader for {REMOTE_HOST}...")
        print("Press Ctrl+C to stop.")
        
        # Prevent system sleep while script is running
        prevent_sleep()
        
        try:
            _do_download() # Initial run
            
            while True:
                print(f"[{datetime.now()}] Waiting {t_hour} hours ({int(SLEEP_DURATION)} seconds) before next run...")
                time.sleep(SLEEP_DURATION)
                print(f"[{datetime.now()}] Waking up for next download cycle.")
                _do_download()
                
        except KeyboardInterrupt:
            print("\nScript stopped by user.")
        finally:
            allow_sleep()
            
    else:
        print(f"Error: Invalid mode '{mode}'. Use 'once' or 'continuous'.")

# --- CONFIGURATION DICTIONARIES REMAIN UNCHANGED BELOW ---

# Traffic Controller Configuration (Banks)
BANKS_CONTROLLER_CONFIG = {
    'host': "10.37.23.200",
    'port': 22,
    'user': "econolite",
    'password': "ecpi2ecpi",
    'remote_folder': "/opt/econolite/set1",
    'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/201_SH-55_and_Banks-Lowman_Rd/raw_data/"
}

# EVO Radar Device Configuration (Banks)
BANKS_EVO_CONFIG = {
    'host': "10.37.23.201", #evo
    'port': 22,
    'user': "evo",
    'password': "root",
    'remote_folder': "/home/evo/Documents/SPM_Data_All",
    'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/201_SH-55_and_Banks-Lowman_Rd/raw_data/"
}

MOSCOW_CONFIGS = [
#    {
#        'host': "10.37.2.66", #Washington & 3rd
#        'port': 22,
#        'user': "econolite",
#        'password': "ecpi2ecpi",
#        'remote_folder': "/opt/econolite/set1",
#        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2066_US-95_Washington_and_3rd_St/raw_data/"
#    },
#    {
#        'host': "10.37.2.67", #Washington & 6th
#        'port': 22,
#        'user': "econolite",
#        'password': "ecpi2ecpi",
#        'remote_folder': "/opt/econolite/set1",
#        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2067_US-95_Washington_and_6th_St/raw_data/"
#    },
#    {
#        'host': "10.37.2.76", #Jackson & 6th
#        'port': 22,
#        'user': "econolite",
#        'password': "ecpi2ecpi",
#        'remote_folder': "/opt/econolite/set1",
#        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2076_US-95_Jackson_and_6th/raw_data/"
#    },
    {
        'host': "10.37.2.68", #US-95 & SH-8
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2068_US-95_and_SH-8/raw_data/"
    },
    {
        'host': "10.37.2.69", #US-95 & Sweet Ave
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2069_US-95_and_Sweet_Ave/raw_data/"
    },
    {
        'host': "10.37.2.70", #US-95 & Palouse River Dr
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2070_US-95_and_Palouse_River_Dr/raw_data/"
    },
    {
        'host': "10.37.2.72", #US-95 & D St
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2072_US-95_and_D_St/raw_data/"
    },
    {
        'host': "10.37.2.79", #SH-8 & Line St
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2079_SH-8_and_Line_St/raw_data/"
    },
    {
        'host': "10.37.2.80", #SH-8 & Peterson
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2080_SH-8_and_Peterson/raw_data/"
    },
    {
        'host': "10.37.2.81", #SH-8 & Perimeter
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2081_SH-8_and_Perimeter/raw_data/"
    },
    {
        'host': "10.37.2.82", #SH-8 & Warbonnet
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2082_SH-8_and_Warbonnet/raw_data/"
    },
    {
        'host': "10.37.64.21", #US-12 & 3rd St
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2121_US-12_and_3rd_St/raw_data/"
    },
    {
        'host': "10.37.64.31", #US-12 & 21st
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2131_US-12_and_21st/raw_data/"
    },
    {
        'host': "10.37.64.41", #US-12 & 18th
        'port': 22,
        'user': "econolite",
        'password': "ecpi2ecpi",
        'remote_folder': "/opt/econolite/set1",
        'local_root_folder' : r"C:/Users/rhansen/Documents/Python/pyatspm/intersections/2141_US-12_and_18th/raw_data/"
    }
]

# %%
for config in MOSCOW_CONFIGS:
    download_remote_files(config, mode='once')
# Out:
# [2026-06-15 07:45:38.560435] Starting SCP download job from 10.37.2.68...
# [2026-06-15 07:45:40.213741] Retrieving 120 files more recent than 2026-06-12 07:00:00...
# Downloading: ECON_10.37.2.68_2026_06_14_0145.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0200.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0215.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0230.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0245.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0300.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0315.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0330.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0345.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0400.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0415.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0430.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0445.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0500.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0515.datZ
# Downloading: ECON_10.37.2.68_2026_06_14_0530.datZ
# ...

# %%
# --- EXAMPLE USAGE ---

# Choose the device you want to download from
CURRENT_CONFIG = BANKS_CONTROLLER_CONFIG
#CURRENT_CONFIG = BANKS_EVO_CONFIG

# Choose the mode and time interval
DOWNLOAD_MODE = 'once'  # Options: 'once', 'continuous'
DOWNLOAD_INTERVAL_HOURS = 0.25 # Run every 15 minutes for continuous mode

# Execute the function
if __name__ == "__main__":
    download_remote_files(
        device_config=CURRENT_CONFIG, 
        mode=DOWNLOAD_MODE, 
        t_hour=DOWNLOAD_INTERVAL_HOURS
    )
# Out:
# [2026-06-15 14:31:34.251959] Starting SCP download job from 10.37.23.200...
# [2026-06-15 14:31:35.778998] Retrieving 7 files more recent than 2026-06-15 13:30:00...
# Downloading: ECON_10.37.23.200_2026_06_15_1345.datZ
# Downloading: ECON_10.37.23.200_2026_06_15_1400.datZ
# Downloading: ECON_10.37.23.200_2026_06_15_1415.datZ
# Downloading: ECON_10.37.23.200_2026_06_15_1430.datZ
# Downloading: ECON_10.37.23.200_2026_06_15_1445.datZ
# Downloading: ECON_10.37.23.200_2026_06_15_1500.datZ
# Downloading: ECON_10.37.23.200_2026_06_15_1515.datZ
# [2026-06-15 14:31:39.597072] State updated to: 2026-06-15 15:15:00
# [2026-06-15 14:31:39.597072] Download job completed successfully.
