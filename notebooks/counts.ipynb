# %%
import sys
from pathlib import Path
from datetime import datetime

# 1. Setup Path (Points to project root so we can import 'src')
# Adjust '.parent' if your notebook is deeper in subfolders
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(project_root / 'src'))

# 2. Import the Reader
from atspm.data import get_combined_counts, get_phase_splits

# %%
intersection = '201_SH-55_and_Banks-Lowman_Rd'
intersection = '2068_US-95_and_SH-8'
db_path = project_root / 'intersections' / intersection / f'{intersection.split("_")[0]}_data.db'
start_date = "2026-01-01"
end_date = "2026-12-31"
bin_len = 15
dets = True

# %%
counts_df = get_combined_counts(db_path, start_date, end_date, 
                                bin_len, hourly=False, include_detectors=dets,
                                output_dir=project_root / 'intersections' / intersection / 'outputs')

# %%
from pathlib import Path
from atspm.data.processing import run_cycle_processing

run_cycle_processing(db_path, reprocess=True)
# Out:
# CycleProcessor: using timezone from metadata: US/Pacific
# Processing 7 dates...
# Processed 2026-02-11: Found 156 cycles using ring_barrier_config
# Processed 2026-02-12: Found 984 cycles using ring_barrier_config
# Processed 2026-02-13: Found 498 cycles using ring_barrier_config
# Processed 2026-02-14: Found 1323 cycles using ring_barrier_config
# Processed 2026-02-15: Found 1092 cycles using ring_barrier_config
# Processed 2026-02-16: Found 1210 cycles using ring_barrier_config
# Processed 2026-02-17: Found 664 cycles using ring_barrier_config
#
# Cycle Processing Complete:
#   Successful: 7
#   Failed: 0
#
# Cycle Processing Statistics:
#   Total cycles:      5,927
#   Days processed:    7
#   Unprocessed days:  0
#   Detection methods: {'ring_barrier_config': 5927}
#   Coordination plans:{0: 4449, 1: 1478}
#   Date range:        2026-02-11T12:41:22.900000-08:00 to 2026-02-17T16:29:56.900000-08:00

# %%
bin_len = 15
report_mode = 'proportion'

phase_df = get_phase_splits(db_path, start_date, end_date, bin_len, report_mode=report_mode,
                            output_dir=project_root / 'intersections' / intersection / 'outputs')
# Out:
# c:\Users\rhansen\Documents\Python\pyatspm\src\atspm\data\reader.py:194: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   merged_df['cycle_start'].fillna(first_cycle, inplace=True)
# c:\Users\rhansen\Documents\Python\pyatspm\src\atspm\data\reader.py:195: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   merged_df['coord_plan'].fillna(first_coord, inplace=True)
# Wrote PhaseSplits_15min_proportion_2026_02_11-2026_02_17.csv
